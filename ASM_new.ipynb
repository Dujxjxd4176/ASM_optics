# %%
config_path = "./src/results/new_design/config.yaml"
import numpy as np; import matplotlib.pyplot as plt # type: ignore
from datetime import datetime
import src.ASM as ASM
import src.math_tool as mt
import src.img_tool as it
import src.load_config as lc
#%matplotlib widget
#%load_ext autoreload
#%autoreload 2
c, π = lc.load(config_path), np.pi
print(f'est memory spike: {c.sim.num_process * c.sim.z_batch_size * c.sim.Nx * c.sim.Ny * 2 * 128 / 8 / 1024**3}GB') # *2 cuz npfft is not in-place operation
print(f'simulation size: sim.Nx={c.sim.Nx}, sim.Ny={c.sim.Ny}, sim.Nz={c.sim.Nz}\nfloat32 (intensity) requirement: {c.Nx * c.Ny * c.Nz * 32 / 8 / 1024 / 1024 / 1024} GB\nz-resolution: {(c.sim.z_end - c.sim.z_start)/c.sim.Nz}μm\nconfig file: {config_path}')
if (np.array([c.sim.Nx, c.sim.Ny]) != np.array(c.aperture.shape)).any():
    raise Exception(f'error: loaded aperture dimension mismatch\nloaded file size: {c.aperture.shape}')
##c.aperture = np.double(c.aperture) * 0
#c.aperture += 1 


plt.imshow(c.aperture.T)
plt.gca().invert_yaxis()
plt.show()
# Out:
# est memory spike: 0.75GB
# simulation size: sim.Nx=2048, sim.Ny=2048, sim.Nz=1000
# float32 (intensity) requirement: 3.9138831198215485 GB
# z-resolution: 10.0μm
# config file: ./src/results/new_design/config.yaml

# %%
import math 
palldiv = 8
perpdiv = 20
lensDist = (2300-1270)+5000
pallBeamWidth = math.tan(math.radians(palldiv))*lensDist
perBeamWidth = math.tan(math.radians(perpdiv))*lensDist
emit = mt.guass(pallBeamWidth, perBeamWidth)
print(pallBeamWidth)
print (perBeamWidth)
xv = np.linspace(-1024,1024,2048)
yv = np.linspace(-1024,1024,2048)
x,y  = np.meshgrid(xv,yv, indexing = "ij")
emission = emit.calc(x,y)
ledDist = mt.dist( x ,y , lensDist,0,0,0)
comp = np.exp(-1j*c.k*ledDist)
res = (np.double(( c.aperture)) )  *emission * comp
# Out:
# 847.4612332554204
# 2194.7405126252

# %%
# compute and save results
ASM.ASM_3D_batch_E2_Multi_Process(res, c.sim.Lx, c.sim.Ly, c.sim.zs, c.λ, c.path.E2, c.sim.z_batch_size, c.saved_xy_range_index, num_process=c.sim.num_process)
time = datetime.now()
print(f'last run: {time.isoformat(timespec="minutes")}')
# Out:
# ASM simulation:   0%|          | 0/167 [00:00<?, ?it/s]/home/dujxjxd/Documents/GitHub/ASM_optics/src/ASM.py:241: ComplexWarning: Casting complex values to real discards the imaginary part
#   np.save(f'{path}/{count}.npy', E2.astype(np.float32))
# ASM simulation:   1%|          | 1/166 [00:00<01:24,  1.96it/s]/home/dujxjxd/Documents/GitHub/ASM_optics/src/ASM.py:241: ComplexWarning: Casting complex values to real discards the imaginary part
#   np.save(f'{path}/{count}.npy', E2.astype(np.float32))
# ASM simulation:   1%|          | 1/167 [00:00<01:42,  1.63it/s]/home/dujxjxd/Documents/GitHub/ASM_optics/src/ASM.py:241: ComplexWarning: Casting complex values to real discards the imaginary part
#   np.save(f'{path}/{count}.npy', E2.astype(np.float32))
# ASM simulation:   1%|          | 1/166 [00:00<01:45,  1.57it/s]/home/dujxjxd/Documents/GitHub/ASM_optics/src/ASM.py:241: ComplexWarning: Casting complex values to real discards the imaginary part
# ...

# %%
# extract results
E2 = ASM.batch_E2_extract(c.Nx, c.Ny, c.Nz, c.path.E2, c.sim.z_batch_size)
time = datetime.now()
print(f'last run: {time.isoformat(timespec="minutes")}')
# Out:
# extracting: 100%|███████████████████████████████████████████████████████████████████████████| 1000/1000 [00:38<00:00, 26.07it/s]
# last run: 2026-01-19T17:06

# %%
# x, y plot at different zs
E2_max = E2.max(axis=(0, 1)) # Nz # find peak intensity
s = 500
order = np.flip(np.argsort(E2_max[s:])) + s
#focal_z_idx = order[0]
layout = [[0, 1, 2], [3,3,3]]
plot_z_idxs = [order[0], order[1], order[2]]                                                              # <-- edit plotted z-location here
E2_plot = [E2[:, :, 0], E2[:, :, -1], E2[:, :, plot_z_idxs[2]]]
# plt.clf()
fig, ax = plt.subplot_mosaic(layout, figsize=(18,12))
fig.suptitle(f'diffraction pattern λ={c.λ*1e3}nm\naxes units: μm', fontsize=20)
fig.tight_layout(pad=1.5)
for i in range(len(plot_z_idxs)):
    tmp = ax[i].imshow(E2_plot[i].T, aspect='equal', cmap='plasma')
    ax[i].invert_yaxis()
    ax[i].set_xticks(c.x_tick_idxs, c.xs[c.x_tick_idxs])
    ax[i].set_yticks(c.y_tick_idxs, c.ys[c.y_tick_idxs])
    ax[i].set_title(f'Z={c.zs[plot_z_idxs[i]]}μm')
    fig.colorbar(tmp, ax=[ax[i]], location='top')
y_idx = c.Ny//2
ax[3].set_title(f'x-z plane (y={c.ys[y_idx]}μm)')
ax[3].invert_yaxis()
tmp = ax[3].imshow(E2[:, y_idx, :], aspect='auto', cmap='plasma')
ax[3].set_xticks(c.z_tick_idxs, c.zs[c.z_tick_idxs]); ax[3].set_yticks(c.x_tick_idxs, c.xs[c.x_tick_idxs])
ax[3].axvline(x=plot_z_idxs[1], color='r'); ax[3].axvline(x=plot_z_idxs[2], color='r')
ax[3].set_xlabel('z axis'); ax[3].set_ylabel('x axis')
fig.colorbar(tmp, ax=[ax[3]], location='right', fraction=0.05, aspect=50)
#plt.tight_layout()
plt.savefig(f'{c.path.results}/diffraction.png', bbox_inches='tight')
plt.show()
s, e = 0, 10
print(f'{s}-th to {e}-th highest intensity\n{E2_max[order][s:e]}\nat\n{c.zs[order][s:e]} μm\nindex\n{order[s:e]}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.14/site-packages/box/box.py:594, in box.box.Box.__getitem__()
#
# KeyError: 'results'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File /usr/lib/python3.14/site-packages/box/box.py:633, in box.box.Box.__getattr__()
#
# File /usr/lib/python3.14/site-packages/box/box.py:621, in box.box.Box.__getitem__()
#
# BoxKeyError: "'results'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File /usr/lib/python3.14/site-packages/box/box.py:635, in box.box.Box.__getattr__()
#
# AttributeError: 'Box' object has no attribute 'results'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# x, y plot at different zs
E2_max = E2.max(axis=(0, 1)) # Nz # find peak intensity
s = 500
order = np.flip(np.argsort(E2_max[s:])) + s
#focal_z_idx = order[0]
layout = [[0, 1, 2], [3,3,3]]
plot_z_idxs = [order[0], order[1], order[2]]                                                              # <-- edit plotted z-location here
E2_plot = [E2[:, :, plot_z_idxs[0]], E2[:, :, plot_z_idxs[1]], E2[:, :, plot_z_idxs[2]]]
# plt.clf()
fig, ax = plt.subplot_mosaic(layout, figsize=(18,12))
fig.suptitle(f'diffraction pattern λ={c.λ*1e3}nm\naxes units: μm', fontsize=20)
fig.tight_layout(pad=1.5)
for i in range(len(plot_z_idxs)):
    tmp = ax[i].imshow(E2_plot[i].T, aspect='equal', cmap='plasma')
    ax[i].invert_yaxis()
    ax[i].set_xticks(c.x_tick_idxs, c.xs[c.x_tick_idxs])
    ax[i].set_yticks(c.y_tick_idxs, c.ys[c.y_tick_idxs])
    ax[i].set_title(f'Z={c.zs[plot_z_idxs[i]]}μm')
    fig.colorbar(tmp, ax=[ax[i]], location='top')
y_idx = c.Ny//2
ax[3].set_title(f'x-z plane (y={c.ys[y_idx]}μm)')
ax[3].invert_yaxis()
tmp = ax[3].imshow(E2[512, :, :], aspect='auto', cmap='plasma')
ax[3].set_xticks(c.z_tick_idxs, c.zs[c.z_tick_idxs]); ax[3].set_yticks(c.x_tick_idxs, c.xs[c.x_tick_idxs])
ax[3].axvline(x=plot_z_idxs[1], color='r'); ax[3].axvline(x=plot_z_idxs[2], color='r')
ax[3].set_xlabel('z axis'); ax[3].set_ylabel('x axis')
fig.colorbar(tmp, ax=[ax[3]], location='right', fraction=0.05, aspect=50)
#plt.tight_layout()
plt.savefig(f'{c.path.results}/diffraction.png', bbox_inches='tight')
plt.show()
s, e = 0, 10
print(f'{s}-th to {e}-th highest intensity\n{E2_max[order][s:e]}\nat\n{c.zs[order][s:e]} μm\nindex\n{order[s:e]}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.14/site-packages/box/box.py:594, in box.box.Box.__getitem__()
#
# KeyError: 'results'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File /usr/lib/python3.14/site-packages/box/box.py:633, in box.box.Box.__getattr__()
#
# File /usr/lib/python3.14/site-packages/box/box.py:621, in box.box.Box.__getitem__()
#
# BoxKeyError: "'results'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File /usr/lib/python3.14/site-packages/box/box.py:635, in box.box.Box.__getattr__()
#
# AttributeError: 'Box' object has no attribute 'results'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#np.save(f'{c.path.results}/focus.npy', E2[:, :, plot_z_idxs[1]])
np.save(f'{c.path.results}/focus.npy', E2[:, y_idx, :])
np.save(f'{c.path.results}/xs.npy', c.xs)
np.save(f'{c.path.results}/x_tick_idxs.npy', c.x_tick_idxs)
np.save(f'{c.path.results}/zs.npy', c.zs)
np.save(f'{c.path.results}/z_tick_idxs.npy', c.z_tick_idxs)

# %%
# for QR part
plot_z_idxs = [0, 500]
content = E2[:, :, plot_z_idxs[1]]
plt.clf()
plt.figure(figsize=(10, 8))
plt.imshow(content.T, aspect=1, cmap='plasma')
plt.gca().invert_yaxis()
plt.xticks(c.x_tick_idxs, c.xs[c.x_tick_idxs].astype(int)); plt.yticks(c.y_tick_idxs, c.ys[c.y_tick_idxs].astype(int))
plt.title(f'x-y plane')
cbar = plt.colorbar()
labels = {content.max(): 'High', content.min(): 'Low'}
cbar.set_ticks(list(labels.keys()))
cbar.ax.set_yticklabels([labels[i] for i in labels.keys()], rotation=90)
plt.savefig(f'{c.path.results}/focus.png', bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 # for QR part
#       2 plot_z_idxs = [0, 500]
# ----> 3 content = E2[:, :, plot_z_idxs[1]]
#       4 plt.clf()
#       5 plt.figure(figsize=(10, 8))
#
# IndexError: index 500 is out of bounds for axis 2 with size 2

# %%
# for 2Fz part
content = E2[:, y_idx, :]
plt.clf()
plt.figure(figsize=(10, 8))
plt.imshow(content, aspect=11.7, cmap='plasma')
plt.xticks(c.z_tick_idxs, c.zs[c.z_tick_idxs].astype(int)); plt.yticks(c.x_tick_idxs, c.xs[c.x_tick_idxs].astype(int))
plt.title(f'x-z plane')
cbar = plt.colorbar()
labels = {content.max(): 'High', content.min(): 'Low'}
cbar.set_ticks(list(labels.keys()))
cbar.ax.set_yticklabels([labels[i] for i in labels.keys()], rotation=90)
plt.savefig(f'{c.path.results}/2Fz.png', bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # for 2Fz part
# ----> 2 content = E2[:, y_idx, :]
#       3 plt.clf()
#       4 plt.figure(figsize=(10, 8))
#
# NameError: name 'y_idx' is not defined

# %%
# this part of code assumes and analyse focal point along z-axis at center of focal plane
# no meaning if no focal at center
# z_idx = order[0]
z_idx1 = plot_z_idxs[1]
z_idx2 = plot_z_idxs[2]
transmitted_power = c.aperture.sum() * c.Δx * c.Δy
incidence_power = 500**2*π # 500μm^2 * π *1 W/μm^2
section_E2_x1 = E2[:, c.Ny//2, z_idx1]
FWHM_width_x1 = mt.FWHM(section_E2_x1, c.xs)
lower_bound_power1, upper_bound_power1, lower_bound_zone1, upper_bound_zone1 = mt.FWHM_power(E2[:, :, z_idx1], c.Δx, c.Δy)

section_E2_x2 = E2[:, c.Ny//2, z_idx2]
FWHM_width_x2 = mt.FWHM(section_E2_x2, c.xs)
lower_bound_power2, upper_bound_power2, lower_bound_zone2, upper_bound_zone2 = mt.FWHM_power(E2[:, :, z_idx2], c.Δx, c.Δy)
plt.clf()
plt.close(fig)
layout = [[0, 1], [2, 2]]
fig, ax = plt.subplot_mosaic(layout, figsize=(16,12))
fig.suptitle(f'intensity λ={c.λ*1e3}nm\nhorizontal-axes units: μm', fontsize=15)
fig.tight_layout(pad=5)
x_idx_span = 64
x_idx = c.Nx//2
ax[0].scatter(c.xs[x_idx - x_idx_span: x_idx + x_idx_span + 1], section_E2_x1[x_idx - x_idx_span: x_idx + x_idx_span + 1])# x axis
ax[0].set_title(f'Z={c.zs[z_idx1]}μm\nx-FWHM width: {FWHM_width_x1:.3f} ± {(c.xs[1]-c.xs[0]):.3f}μm\nfocal power / incidence: {lower_bound_power1/incidence_power*100:.3f}% ~ {upper_bound_power1/incidence_power*100:.3f}%\nfocal power / transmittion: {lower_bound_power1/transmitted_power*100:.3f}% ~ {upper_bound_power1/transmitted_power*100:.3f}%')
ax[0].set_xlabel('x axis')

ax[1].scatter(c.xs[x_idx - x_idx_span: x_idx + x_idx_span + 1], section_E2_x2[x_idx - x_idx_span: x_idx + x_idx_span + 1])# x axis
ax[1].set_title(f'Z={c.zs[z_idx2]}μm\nx-FWHM width: {FWHM_width_x2:.3f} ± {(c.xs[1]-c.xs[0]):.3f}μm\nfocal power / incidence: {lower_bound_power2/incidence_power*100:.3f}% ~ {upper_bound_power2/incidence_power*100:.3f}%\nfocal power / transmittion: {lower_bound_power2/transmitted_power*100:.3f}% ~ {upper_bound_power2/transmitted_power*100:.3f}%')
ax[1].set_xlabel('x axis')

ax[2].plot(c.zs, E2[c.Nx//2, c.Ny//2, :])# z axis
ax[2].set_xlabel('z axis')
ax[2].axvline(x=c.zs[plot_z_idxs[1]], color='r')
ax[2].axvline(x=c.zs[plot_z_idxs[2]], color='r')
plt.savefig(f'{c.path.results}/focal.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 5
#       1 # this part of code assumes and analyse focal point along z-axis at center of focal plane
#       2 # no meaning if no focal at center
#       3 # z_idx = order[0]
#       4 z_idx1 = plot_z_idxs[1]
# ----> 5 z_idx2 = plot_z_idxs[2]
#       6 transmitted_power = c.aperture.sum() * c.Δx * c.Δy
#       7 incidence_power = 500**2*π # 500μm^2 * π *1 W/μm^2
#
# IndexError: list index out of range

# %%
it.arr_2_mp4(np.moveaxis(E2, -1, 0), path=f'{c.path.results}/E2.mp4', fps=60, title=lambda z_idx: f'z: {c.zs[z_idx]}μm')
